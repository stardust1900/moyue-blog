# %% [markdown]
# ---
# title: "我的第一个 Notebook 博客"
# date: 2026-08-09
# category: "技术笔记"
# tags: ["Jupyter", "Astro", "教程"]
# description: "演示 .ipynb 如何被渲染为博客文章：代码高亮、文本输出与图片输出。"
# coverEmoji: "📓"
# draft: false
# ---
#
# # 第一个 Notebook 文章
#
# 这是一段 **Markdown** 说明，支持 `代码`、列表与表格：
#
# | 库 | 用途 |
# | --- | --- |
# | numpy | 数值计算 |
# | matplotlib | 绘图 |
#
# ## 小节标题
#
# 下面是代码示例。

# %%
nums = [1, 2, 3, 4, 5]
total = sum(nums)
print("Hello from a Jupyter notebook!")
print("sum =", total)
squares = [n * n for n in nums]
squares
# Out:
# Hello from a Jupyter notebook!
# sum = 15
# [1, 4, 9, 16, 25]

# %%
# 1x1 红色像素，验证图片内联渲染
print("见图：")
